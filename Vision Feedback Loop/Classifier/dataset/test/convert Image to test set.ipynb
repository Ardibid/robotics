# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import misc


from os import listdir
from os.path import isfile, join
import cv2

import time
from time import gmtime, strftime
import imageio

# %%
path = "./source/GOPR1401.JPG"
img = misc.imread(path)
imgCrop = img[500:1500, 500:1500]
size = 64
images = []
for i in range (1000//size):
    for j in range (1000//size):
        tmp =  imgCrop[i*size:(i+1)*size, j*size:(j+1)*size] 
        name = "test_{}.jpg".format(i*size+j)
        misc.imsave(name,tmp)
        images.append(tmp)

# %%
plt.imshow((images[10]))
plt.show()
